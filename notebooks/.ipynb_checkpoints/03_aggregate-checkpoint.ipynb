# %% [markdown]
# # 03 - Camada Ouro: Dados Prontos para Consumo e Análise

# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/silver/breweries.parquet/", engine="pyarrow")
print(df.head())
# Out:
#                                      ID  \
# 0  0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 1  4f4b5b34-d572-4dff-a18f-47e507c073e6
# 2  0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 3  4f4b5b34-d572-4dff-a18f-47e507c073e6
# 4  0faa0fb2-fffa-416d-9eab-46f67477c8ef
#
#                                             NAME TYPE BREWERY    CITY  \
# 0  12 West Brewing Company - Production Facility        MICRO    MESA
# 1                                   1912 Brewing        MICRO  TUCSON
# 2  12 West Brewing Company - Production Facility        MICRO    MESA
# 3                                   1912 Brewing        MICRO  TUCSON
# 4  12 West Brewing Company - Production Facility        micro    Mesa
#
#   POSTAL CODE        COUNTRY   LONGITUDE   LATITUDE       PHONE  \
# 0       85207  UNITED STATES -111.586066  33.436188           0
# 1  85745-1444  UNITED STATES -110.992750  32.246737  5202564851
# 2       85207  UNITED STATES -111.586066  33.436188           0
# 3  85745-1444  UNITED STATES -110.992750  32.246737  5202564851
# 4       85207  United States -111.586066  33.436188           0
#
#            URL WEBSITE STATE PROVINCE
# 0              Unknown        ARIZONA
# 1  www.1912brewing.com        ARIZONA
# 2              Unknown        ARIZONA
# 3  www.1912brewing.com        ARIZONA
# 4              Unknown        ARIZONA

# %%
df_state_type = (
    df.groupby(['STATE PROVINCE', 'TYPE BREWERY'],observed=True)
      .size()
      .reset_index(name='COUNT_BREWERY')
      .sort_values(by='COUNT_BREWERY',ascending=False)
)
display(df_state_type)
# Out:
#     STATE PROVINCE TYPE BREWERY  COUNT_BREWERY
# 49          OREGON        LARGE             20
# 22         INDIANA        MICRO             15
# 60       WISCONSIN        MICRO             10
# 48          OREGON      BREWPUB             10
# 0          ARIZONA        MICRO             10
# ..             ...          ...            ...
# 41  NORTH CAROLINA      brewpub              1
# 29   MASSACHUSETTS        micro              1
# 39        NEW YORK      brewpub              1
# 37          NEVADA        micro              1
# 31        MICHIGAN        micro              1
#
# [62 rows x 3 columns]

# %%
df_country = (
             df.groupby(['COUNTRY'], observed=True)
               .size()
               .reset_index(name='COUNT_COUNTY')
               .sort_values(by='COUNT_COUNTY',ascending=False)
)
display(df_country)
# Out:
#          COUNTRY  COUNT_COUNTY
# 2  UNITED STATES           195
# 3  United States            39
# 0        IRELAND             5
# 1        Ireland             1

# %%
df_type = (
    df.groupby(['TYPE BREWERY'], observed=True)
      .size()
      .reset_index(name='COUNT_TYPE')
      .sort_values(by='COUNT_TYPE', ascending=False)
)

display(df_type)
# Out:
#   TYPE BREWERY  COUNT_TYPE
# 3        MICRO         120
# 2        LARGE          35
# 0      BREWPUB          30
# 8        micro          24
# 1       CLOSED          10
# 7        large           7
# 5      brewpub           6
# 4   PROPRIETOR           5
# 6       closed           2
# 9   proprietor           1

# %%
df_agg_estado = (
    df.groupby(['STATE PROVINCE'],observed=True)
      .size()
      .reset_index(name='TOTAL BREWERIES')
      .sort_values(by='TOTAL BREWERIES', ascending=False)
)
display(df_agg_estado)
# Out:
#     STATE PROVINCE  TOTAL BREWERIES
# 18          OREGON               36
# 1       CALIFORNIA               24
# 2         COLORADO               24
# 6          INDIANA               18
# 0          ARIZONA               12
# 21      WASHINGTON               12
# 16            OHIO               12
# 22       WISCONSIN               12
# 8            LAOIS                6
# 9    MASSACHUSETTS                6
# 10        MICHIGAN                6
# 7             IOWA                6
# 12     MISSISSIPPI                6
# 13          NEVADA                6
# 14        NEW YORK                6
# 15  NORTH CAROLINA                6
# 5         ILLINOIS                6
# 17        OKLAHOMA                6
# 4            IDAHO                6
# 19    PENNSYLVANIA                6
# 20           TEXAS                6
# 3         DELAWARE                6
# 11       MINNESOTA                6

# %%
top_states = df_agg_estado.head(10)
display(top_states)
# Out:
#    STATE PROVINCE  TOTAL BREWERIES
# 18         OREGON               36
# 1      CALIFORNIA               24
# 2        COLORADO               24
# 6         INDIANA               18
# 0         ARIZONA               12
# 21     WASHINGTON               12
# 16           OHIO               12
# 22      WISCONSIN               12
# 8           LAOIS                6
# 9   MASSACHUSETTS                6

# %%
df_sem_site = (
    df[~df['URL WEBSITE'].str.contains(r'\.', na=False)]
      .sort_values(by=['STATE PROVINCE', 'NAME'], ascending=[True, True])
)
print("*-----------------------------------------------*")
print(f"Cervejarias SEM site: {len(df_sem_site)} de {len(df)} ({round(100 * len(df_sem_site) / len(df), 2)}%)")
print("*-----------------------------------------------*")
display(df_sem_site)
# Out:
# *-----------------------------------------------*
# Cervejarias SEM site: 48 de 240 (20.0%)
# *-----------------------------------------------*
#                                        ID  \
# 0    0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 2    0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 4    0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 6    0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 8    0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 10   0faa0fb2-fffa-416d-9eab-46f67477c8ef
# 36   1988eb86-f0a2-4674-ba04-02454efa0d31
# 40   1988eb86-f0a2-4674-ba04-02454efa0d31
# 44   1988eb86-f0a2-4674-ba04-02454efa0d31
# 48   1988eb86-f0a2-4674-ba04-02454efa0d31
# 52   1988eb86-f0a2-4674-ba04-02454efa0d31
# 56   1988eb86-f0a2-4674-ba04-02454efa0d31
# 78   7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3
# 81   7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3
# 84   7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3
# 87   7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3
# 90   7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3
# 93   7531dbd8-afc9-4b5b-95bc-7ece7f2c0bf3
# 80   add7f978-942e-4d56-b209-c80837a51d69
# 83   add7f978-942e-4d56-b209-c80837a51d69
# 86   add7f978-942e-4d56-b209-c80837a51d69
# 89   add7f978-942e-4d56-b209-c80837a51d69
# 115  49201-7010  UNITED STATES  -84.431168  42.286672  5172581346     Unknown
# 116  49201-7010  United States  -84.431168  42.286672  5172581346     Unknown
# 117  49201-7010  UNITED STATES  -84.431168  42.286672  5172581346     Unknown
# 118  49201-7010  UNITED STATES  -84.431168  42.286672  5172581346     Unknown
# 119  49201-7010  UNITED STATES  -84.431168  42.286672  5172581346     Unknown
# 126       38860  UNITED STATES  -88.750264  34.001703  6623055907     Unknown
# 127       38860  UNITED STATES  -88.750264  34.001703  6623055907     Unknown
# 128       38860  United States  -88.750264  34.001703  6623055907     Unknown
# 129       38860  UNITED STATES  -88.750264  34.001703  6623055907     Unknown
# 130       38860  UNITED STATES  -88.750264  34.001703  6623055907     Unknown
# 131       38860  UNITED STATES  -88.750264  34.001703  6623055907     Unknown
# 169  97703-2465  UNITED STATES -121.328802  44.057565  5415851007     Unknown
# 175  97703-2465  UNITED STATES -121.328802  44.057565  5415851007     Unknown
# 181  97703-2465  United States -121.328802  44.057565  5415851007     Unknown
# 187  97703-2465  UNITED STATES -121.328802  44.057565  5415851007     Unknown
# 193  97703-2465  UNITED STATES -121.328802  44.057565  5415851007     Unknown
# 199  97703-2465  UNITED STATES -121.328802  44.057565  5415851007     Unknown
# 171       97701  UNITED STATES -121.280954  44.091211  5415851007     Unknown
# 177       97701  UNITED STATES -121.280954  44.091211  5415851007     Unknown
# 183       97701  United States -121.280954  44.091211  5415851007     Unknown
# 189       97701  UNITED STATES -121.280954  44.091211  5415851007     Unknown
# 195       97701  UNITED STATES -121.280954  44.091211  5415851007     Unknown
# 201       97701  UNITED STATES -121.280954  44.091211  5415851007     Unknown
#
#     STATE PROVINCE
# 0          ARIZONA
# 2          ARIZONA
# 4          ARIZONA
# 6          ARIZONA
# 8          ARIZONA
# 10         ARIZONA
# 36        COLORADO
# 40        COLORADO
# 44        COLORADO
# 48        COLORADO
# 52        COLORADO
# 56        COLORADO
# 78         INDIANA
# 81         INDIANA
# 84         INDIANA
# 87         INDIANA
# 90         INDIANA
# 93         INDIANA
# 80         INDIANA
# 83         INDIANA
# 86         INDIANA
# 89         INDIANA
# 92         INDIANA
# 95         INDIANA
# 114       MICHIGAN
# 115       MICHIGAN
# 116       MICHIGAN
# 117       MICHIGAN
# 118       MICHIGAN
# 119       MICHIGAN
# 126    MISSISSIPPI
# 127    MISSISSIPPI
# 128    MISSISSIPPI
# 129    MISSISSIPPI
# 130    MISSISSIPPI
# 131    MISSISSIPPI
# 169         OREGON
# 175         OREGON
# 181         OREGON
# 187         OREGON
# 193         OREGON
# 199         OREGON
# 171         OREGON
# 177         OREGON
# 183         OREGON
# 189         OREGON
# 195         OREGON
# 201         OREGON

# %%
df_state_type.to_parquet('../data/gold/df_state_type.parquet', index=False)
df_country.to_parquet('../data/gold/df_country.parquet', index=False)
df_type.to_parquet('../data/gold/df_type.parquet', index=False)
df_agg_estado.to_parquet('../data/gold/df_agg_estado.parquet', index=False)
top_states.to_parquet('../data/gold/top_states.parquet', index=False)
df_sem_site.to_parquet('../data/gold/df_sem_site.parquet', index=False)
